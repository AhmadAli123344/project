# %%
import pickle
pickle_file_path= '/content/drive/MyDrive/project_data/train_data_new.pkl'

# Save train_data to a pickle file
with open(pickle_file_path, 'rb') as file:
  X_train,y_train=pickle.load(file)

# %%
X_train.shape,y_train.shape
# Out:
# ((1329, 300, 300), (1329,))

# %%
import tensorflow
import keras
from keras.models import Sequential
from keras.layers import Conv2D ,MaxPooling2D ,Flatten ,Dropout ,Dense
from keras.utils import to_categorical

# %%
model=Sequential()

model.add(Conv2D(30,(10,10),activation='relu',input_shape=(300,300,1)))

model.add(MaxPooling2D(3,3))

model.add(Conv2D(42,(8,8),activation='relu'))

model.add(MaxPooling2D(2,2))

model.add(Flatten())
model.add(Dense(100,activation='relu'))

model.add(Dense(80,activation='relu'))

model.add(Dense(50,activation='relu'))

model.add(Dense(32,activation='relu'))


model.add(Dense(2,activation='softmax'))
g=model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 291, 291, 30)      3030
#
#  max_pooling2d (MaxPooling2D  (None, 97, 97, 30)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 42)        80682
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 42)       0
#  2D)
#
#  flatten (Flatten)           (None, 85050)             0
#
#  dense (Dense)               (None, 100)               8505100
#
#  dense_1 (Dense)             (None, 80)                8080
#
#  dense_2 (Dense)             (None, 50)                4050
#
#  dense_3 (Dense)             (None, 32)                1632
#
#  dense_4 (Dense)             (None, 2)                 66
#
# ...
# Total params: 8,602,640
# Trainable params: 8,602,640
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_train_encoded = to_categorical(y_train)
# y_test_encoded = to_categorical(y2_test)

h=model.fit(X_train,y_train_encoded, batch_size=50, epochs=50, validation_split=0.1 ,shuffle = True)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 21s 231ms/step - loss: 0.6073 - accuracy: 0.6848 - val_loss: 1.1551 - val_accuracy: 0.1880
# Epoch 2/50
# 24/24 [==============================] - 2s 83ms/step - loss: 0.4979 - accuracy: 0.7826 - val_loss: 0.9813 - val_accuracy: 0.3684
# Epoch 3/50
# 24/24 [==============================] - 2s 85ms/step - loss: 0.4731 - accuracy: 0.8027 - val_loss: 1.4429 - val_accuracy: 0.1805
# Epoch 4/50
# 24/24 [==============================] - 2s 82ms/step - loss: 0.4666 - accuracy: 0.8035 - val_loss: 1.3295 - val_accuracy: 0.2556
# Epoch 5/50
# 24/24 [==============================] - 2s 80ms/step - loss: 0.4139 - accuracy: 0.8261 - val_loss: 1.7080 - val_accuracy: 0.2105
# Epoch 6/50
# 24/24 [==============================] - 2s 80ms/step - loss: 0.3563 - accuracy: 0.8604 - val_loss: 1.6647 - val_accuracy: 0.2406
# Epoch 7/50
# ...

# %%
# y_preds = model.predict(X_test)
# y_preds_argmax = np.argmax(y_preds ,axis = 1)
# accuracy_score(y2_test ,y_preds_argmax)
# confusion_matrix(y2_test ,y_preds_argmax)

# %%
# confusion_matrix(y2_test ,y_preds_argmax)

# %%
import tensorflow as tf

# Assuming 'model' is your trained CNN model
# model.save('/content/drive/MyDrive/model_files', save_format='tf')
tf.keras.models.save_model(model,'Project_Model.hdf5')
# Save the model
# Replace 'your_model_directory' with the path to your chosen directory.
# model.save('D:\model')

# model.save('my_cnn_model')
